# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
# import MySQLdb
import time
import json

#consumer key, consumer secret, access token, access secret.
ckey="4DD4INFicbA5XlJ3WT8atYac8"
csecret="dK9y34jG1nPzth7cGwmqveC72yyhlsU6Jm7mBiuB7gVw8xeEDm"
atoken="845895183711567876-68Duixf5MwM6V4f24vClGV86PdfVQYe"
asecret="5QSSZD34ejllVQQhfCFmsaXjIVaxCjLDrXMg65xu9Q2c8"

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        tweet = all_data["text"]
        username = all_data["user"]["screen_name"]
#         print((username,tweet))
        with open('../Project/Collected_Data/'+username, 'w') as outfile:  
            json.dump(data, outfile)
        return True

    def on_error(self, status):
        print (status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["#amazon"])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\Users\Rishabh\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     255         try:
# --> 256             return self.connection.recv_into(*args, **kwargs)
#     257         except OpenSSL.SSL.SysCallError as e:
#
# C:\Users\Rishabh\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# C:\Users\Rishabh\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1148         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1149             raise WantReadError()
#    1150         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# ...
